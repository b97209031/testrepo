# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Ying-Lin Chen, want to be EUV lithography RD**

# %% [markdown]
# *Interested in how to apply machine learning or deep learning to solve image data. For example CDSEM image or other inspection results.*
# *I am also interestd in how data science can help in the process control part (feedback loop to overlay/CD control)*
# *Data science give me different approach than only physical or chemical insight, allowing me to handle great amount of data.*

# %% [markdown]
# ### import math library
# ### print text "pi square is" + the value

# %%
import math
a=math.pi
print("pi square is", a**2)
# Out:
# pi square is 9.869604401089358

# %% [markdown]
# #### Useful information to complete this assignment
# ***
# * [Markdown Cheatsheet][1]
# * [Python Tutorial][2]
#
# Resource:
# ![alt text][logo1]
#
# ![alt text][logo2]
#
# [logo1]: https://upload.wikimedia.org/wikipedia/commons/f/f8/Python_logo_and_wordmark.svg
#
# [logo2]: https://upload.wikimedia.org/wikipedia/commons/3/38/Jupyter_logo.svg
#
# [1]:https://github.com/adam-p/markdown-here/wiki/Markdown-Cheatsheet#hr
# [2]:https://docs.python.org/3/tutorial/index.html
